# %% [markdown]
# <a href="https://colab.research.google.com/github/nanangyudi/2020pds_d/blob/main/TugasExploreNBA_Alam_Nur_Muhammad_205150409111031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Aal1305/Tugas-Data-Saintis/main/all_seasons.csv'

# %% [markdown]
# **Deskripsi Tujuan Bisnis** :
#
#
# 1.   Untuk mengetahui jumlah data pemain basket NBA Amerika
# 2.   Untuk mengetahui berat badan, tinggi badan, dan karir sebagai pemain NBA
# 3.   Sebagai bahan perbandingan dari performa setiap pemain ke pemain dari banyak prestasi
#
#
#
# **Analisa Pendekatan** :
#
#
# 1. Pada analisa data ini kami menggunakan Exploratory Data Analysis (EDA)adalah pendekatan untuk menganalisis set data untuk merangkum karakteristik     utama mereka, seringkali dengan metode visual dan pendekatan untuk menganalisis set data untuk merangkum karakteristik utama mereka, seringkali dengan metode visual.
#
#
# **Pengumpulan data** :
# 1. Mendapatkan data melalui website kaggle.com dengan berjudul "NBA PLAYER"
#
# **Pemahaman terhadap data yang dikumpulkan**:
#
# 1. Data yang ditunjukan memuat informasi pemain NBA amaerika dan beserta prestasinya.
# 2. Beberapa data  tersebut antara lain Dennis Rodman, Dwayne Schintzius	, Ed O'Bannon, Ed Pinckney, Eddie Jones
#
# **Persiapan data** :
# 1. Library yang saya gunakan dalam explorasi data adalah pandas, Matpolib, Seaborn
#
# **Pemodelan data** :
# 1. Explorasi data yang telah saya lakukan menghasilkan sebuah informasi berupa scater scatter plot, diagram histogram dan boxplot.
#
# **Evaluasi Model**
#
# pada data yang telah di analisis menunjukkan diagram histogram yang tidak normal, data tersebut adalah jumlah player NBA hasil dari scratter plot yang telah dianalisis menunjukan nilai x semakin besar dan semakin besar pula nilai y. Dapat disimpulkan variabel yang diteliti memiliki hubungan linear atau positif dan memiliki hubungan yang sangat kuat.
# Dari hasil analisis data boxplot diatas dapat disimpulkan menunjukkan mean diantara rentang nilai 70, data minimal yaitu 10, dan data maksimal dengan nilai 100.

# %%
import pandas as pd
df = pd.read_csv(url, error_bad_lines=False)
df.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation  ...  ts_pct  ast_pct   season
# 0           0      Dennis Rodman               CHI  ...   0.479    0.113  1996-97
# 1           1  Dwayne Schintzius               LAC  ...   0.430    0.048  1996-97
# 2           2       Earl Cureton               TOR  ...   0.376    0.148  1996-97
# 3           3        Ed O'Bannon               DAL  ...   0.399    0.077  1996-97
# 4           4        Ed Pinckney               MIA  ...   0.611    0.040  1996-97
#
# [5 rows x 22 columns]

# %% [markdown]
# **Menampilkan data :**

# %%
df.head(10)
# Out:
#    Unnamed: 0        player_name team_abbreviation  ...  ts_pct  ast_pct   season
# 0           0      Dennis Rodman               CHI  ...   0.479    0.113  1996-97
# 1           1  Dwayne Schintzius               LAC  ...   0.430    0.048  1996-97
# 2           2       Earl Cureton               TOR  ...   0.376    0.148  1996-97
# 3           3        Ed O'Bannon               DAL  ...   0.399    0.077  1996-97
# 4           4        Ed Pinckney               MIA  ...   0.611    0.040  1996-97
# 5           5      Eddie Johnson               HOU  ...   0.541    0.102  1996-97
# 6           6        Eddie Jones               LAL  ...   0.559    0.149  1996-97
# 7           7     Elden Campbell               LAL  ...   0.520    0.087  1996-97
# 8           8  Eldridge Recasner               ATL  ...   0.539    0.141  1996-97
# 9           9       Elliot Perry               MIL  ...   0.557    0.262  1996-97
#
# [10 rows x 22 columns]

# %% [markdown]
# **Melihat Dimensi :**

# %%
dimensi      = df.shape
panjang_data = len(df)
print(f'Dimensi data adalah {dimensi[0]} baris, dan {dimensi[1]} kolom')
print(f'Panjang data adalah {panjang_data} baris')
# Out:
# Dimensi data adalah 11145 baris, dan 22 kolom
# Panjang data adalah 11145 baris

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# player_name          0
# team_abbreviation    0
# age                  0
# player_height        0
# player_weight        0
# college              0
# country              0
# draft_year           0
# draft_round          0
# draft_number         0
# gp                   0
# pts                  0
# reb                  0
# ast                  0
# net_rating           0
# oreb_pct             0
# dreb_pct             0
# usg_pct              0
# ts_pct               0
# ast_pct              0
# season               0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
fig=plt.figure()

# %% [markdown]
# **Cek Missing Values:**

# %%
df.player_name.value_counts()
# Out:
# Vince Carter        22
# Dirk Nowitzki       21
# Kevin Garnett       20
# Kobe Bryant         20
# Jason Terry         19
#                     ..
# Eric Paschall        1
# Javonte Green        1
# Darrin Hancock       1
# Cory Carr            1
# David Vanterpool     1
# Name: player_name, Length: 2235, dtype: int64

# %% [markdown]
# Pemodelan Data

# %% [markdown]
# **Melihat Frekuensi Data Berdasarkan Review Tiap Tahunnya**

# %%
plt.hist(df['age'], bins = 10, edgecolor = 'black')
plt.suptitle('(url, error_bad_lines=False)', fontsize=14, fontweight='bold')
plt.title('Berdasarkan age')
plt.xlabel('age')
plt.ylabel('player_weight')
plt.show()

# %% [markdown]
# **Melihat keterkaitan hubungan data berdasarkan Tahun diterbitkannya buku dengan Review buku menggunakan Scatter Plot**

# %%
fig=plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(df['age'],df['player_height'])
plt.title('Umur dan Tinggi Pemain')
plt.xlabel('age')
plt.ylabel('player_height')
plt.show()

# %%
import seaborn as sns

# %% [markdown]
# **Box-plot keterkaitan User Rating terhadap Genre buku**

# %%
sns.boxplot(df['age'])
sns.despine()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Tabel Frekuensi**

# %%
test= df.groupby(['age','player_height'])
test.size()
# Out:
# age   player_height
# 18.0  200.66           1
#       210.82           1
#       213.36           1
# 19.0  185.42           1
#       193.04           3
#                       ..
# 42.0  218.44           1
# 43.0  198.12           1
#       215.90           1
#       218.44           1
# 44.0  213.36           1
# Length: 460, dtype: int64

# %% [markdown]
# **Mengelompokkan Variabel**

# %%
test= df.groupby(['age'])
test.describe()
# Out:
#      Unnamed: 0                            ... ast_pct
#           count         mean          std  ...     50%      75%    max
# age                                        ...
# 18.0        3.0  1568.666667  2356.978857  ...  0.0440  0.09400  0.144
# 19.0       67.0  6122.955224  3422.620480  ...  0.0850  0.13450  1.000
# 20.0      246.0  6858.918699  3159.243706  ...  0.0905  0.15150  0.667
# 21.0      425.0  6522.569412  3074.374571  ...  0.0920  0.15300  0.451
# 22.0      678.0  6284.584071  3154.643805  ...  0.0950  0.16175  0.615
# 23.0     1039.0  5771.787295  3173.717504  ...  0.0950  0.16650  0.667
# 24.0     1143.0  5694.013998  3181.294210  ...  0.1000  0.17350  1.000
# 25.0     1025.0  5699.336585  3179.762655  ...  0.0990  0.17500  0.750
# 26.0      933.0  5683.094319  3240.011229  ...  0.1030  0.18100  0.583
# 27.0      891.0  5502.485971  3268.563305  ...  0.1060  0.18650  0.505
# 28.0      774.0  5470.202842  3201.112303  ...  0.1075  0.18975  0.636
# ...

# %% [markdown]
# **Pemetaan Map**

# %%
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(df.corr(),annot=True, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title("NBA Player",fontweight="bold")
plt.show()

# %% [markdown]
# Dilihat dari Corelation Mapping diatas dapat disimpulkan bahwa yang mempunyai:
#
# *   Korelasi positif yaitu kolom "player_height" dan "player_weight", dan "oreb_pct"
# *   Korelasi negatif yaitu "gp", "pts dan act", "usg_pct dan ts_pct
# ".

# %% [markdown]
# **Evaluasi Model**

# %%
df[["player_weight","player_height"]].nlargest(20,"player_weight").plot.bar(x="player_weight",y="player_height",width=0.4,)#'vertical', 'horizontal',color=color
plt.title("player weight dan player height terbanyak",fontsize=20)
plt.xlabel("age",fontsize=15)
plt.ylabel("Frekuensi player height",fontsize=15)
plt.show()

# %% [markdown]
# **Brand dengan total review tertinggi**

# %%
df[df.player_height == max(df.player_height)]
# Out:
#       Unnamed: 0       player_name team_abbreviation  ...  ts_pct  ast_pct   season
# 92            92  Gheorghe Muresan               WAS  ...   0.618    0.024  1996-97
# 1212        1212  Gheorghe Muresan               NJN  ...   0.000    0.000  1998-99
# 1408        1408  Gheorghe Muresan               NJN  ...   0.492    0.056  1999-00
#
# [3 rows x 22 columns]

# %% [markdown]
# Player tertinggi dengan tinggi 231.14 adalah Gheorghe Muresan

# %% [markdown]
# **Brand dengan total review terendah**

# %%
df[df.player_height == min(df.player_height)]
# Out:
#       Unnamed: 0    player_name team_abbreviation  ...  ts_pct  ast_pct   season
# 401          401  Muggsy Bogues               CHH  ...   0.554    0.366  1996-97
# 483          483  Muggsy Bogues               GSW  ...   0.492    0.344  1997-98
# 1123        1123  Muggsy Bogues               GSW  ...   0.539    0.338  1998-99
# 1705        1705  Muggsy Bogues               TOR  ...   0.517    0.266  1999-00
# 2020        2020  Muggsy Bogues               TOR  ...   0.000    0.294  2000-01
#
# [5 rows x 22 columns]

# %% [markdown]
# Player badan terendah 160.02 adalah Muggsy Bogues

# %%
df[['player_name',	'team_abbreviation',	'college',	'country',	'age',	'pts', 'player_height',	'player_weight',	'draft_year']].nlargest(10,"player_height")
# Out:
#            player_name team_abbreviation  ... player_weight draft_year
# 92    Gheorghe Muresan               WAS  ...    137.438376       1993
# 1212  Gheorghe Muresan               NJN  ...    137.438376       1993
# 1408  Gheorghe Muresan               NJN  ...    137.438376       1993
# 242      Shawn Bradley               DAL  ...    112.490816       1993
# 647      Shawn Bradley               DAL  ...    112.490816       1993
# 1053     Shawn Bradley               DAL  ...    119.294696       1993
# 1558     Shawn Bradley               DAL  ...    119.294696       1993
# 2186     Shawn Bradley               DAL  ...    120.201880       1993
# 2415     Shawn Bradley               DAL  ...    120.201880       1993
# 2638     Shawn Bradley               DAL  ...    124.737800       1993
#
# [10 rows x 9 columns]

# %% [markdown]
# Hasil diatas adalah 10 produk dengan total review terbanyak adalah Gheoghe Muresan dengan tingkat teratas dengan nilai pts 10.6, tinggi badan 231.14, dan berat badan 137.438376

# %% [markdown]
# **Clustering Menggunakan K-Means**

# %% [markdown]
# Buat Cluster

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
retail = pd.read_csv("https://raw.githubusercontent.com/Aal1305/Tugas-Data-Saintis/main/all_seasons.csv")
retail.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation  ...  ts_pct  ast_pct   season
# 0           0      Dennis Rodman               CHI  ...   0.479    0.113  1996-97
# 1           1  Dwayne Schintzius               LAC  ...   0.430    0.048  1996-97
# 2           2       Earl Cureton               TOR  ...   0.376    0.148  1996-97
# 3           3        Ed O'Bannon               DAL  ...   0.399    0.077  1996-97
# 4           4        Ed Pinckney               MIA  ...   0.611    0.040  1996-97
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11145 entries, 0 to 11144
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         11145 non-null  int64
#  1   player_name        11145 non-null  object
#  2   team_abbreviation  11145 non-null  object
#  3   age                11145 non-null  float64
#  4   player_height      11145 non-null  float64
#  5   player_weight      11145 non-null  float64
#  6   college            11145 non-null  object
#  7   country            11145 non-null  object
#  8   draft_year         11145 non-null  object
#  9   draft_round        11145 non-null  object
#  10  draft_number       11145 non-null  object
#  11  gp                 11145 non-null  int64
#  12  pts                11145 non-null  float64
#  13  reb                11145 non-null  float64
#  14  ast                11145 non-null  float64
#  15  net_rating         11145 non-null  float64
# ...

# %%
retail = retail.drop(["age", "player_weight", "country", "gp"], axis = 1)
retail.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation  ...  ts_pct ast_pct   season
# 0           0      Dennis Rodman               CHI  ...   0.479   0.113  1996-97
# 1           1  Dwayne Schintzius               LAC  ...   0.430   0.048  1996-97
# 2           2       Earl Cureton               TOR  ...   0.376   0.148  1996-97
# 3           3        Ed O'Bannon               DAL  ...   0.399   0.077  1996-97
# 4           4        Ed Pinckney               MIA  ...   0.611   0.040  1996-97
#
# [5 rows x 18 columns]

# %%
df_x = df.iloc[:, 13:15]
df_x.head()
# Out:
#     reb  ast
# 0  16.1  3.1
# 1   1.5  0.3
# 2   1.0  0.4
# 3   2.3  0.6
# 4   2.4  0.2

# %%
x_array = np.array(df_x)
print(x_array)
# Out:
# [[16.1  3.1]
#  [ 1.5  0.3]
#  [ 1.   0.4]
#  ...
#  [ 5.1  1.1]
#  [ 3.   0.4]
#  [ 1.4  0.5]]

# %% [markdown]
# - **Visualisasi Data**
#
# Visualisasikan data yang ada dengan plot poin-poin dan periksa apakah kita dapat melihat kelompok manapun, sehingga didapatkan hasil visualisasi data seperti gambar berikut.

# %%
sns.scatterplot(x="player_weight", y="player_height", data=df, s=100, color="red" , alpha = 0.5)

# %% [markdown]
# Mengubah variabel data frame menjadi array sebelum menentukan nilai K.

# %%
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x_array)
x_scaled
# Out:
# array([[0.98773006, 0.26495726],
#        [0.09202454, 0.02564103],
#        [0.06134969, 0.03418803],
#        ...,
#        [0.31288344, 0.09401709],
#        [0.18404908, 0.03418803],
#        [0.08588957, 0.04273504]])

# %%
from sklearn.cluster import KMeans

# %%
# Menentukan dan mengkonfigurasi fungsi kmeans
kmeans = KMeans(n_clusters = 5, random_state=123)
# Menentukan kluster dari data
kmeans.fit(x_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=123, tol=0.0001, verbose=0)

# %% [markdown]
# Menstandarkan kembali ukuran variabel array.

# %%
print(kmeans.cluster_centers_)
# Out:
# [[0.10187193 0.0612779 ]
#  [0.17517406 0.27675422]
#  [0.26178323 0.57586325]
#  [0.28723338 0.09812599]
#  [0.54635139 0.17851365]]

# %%
# Menampilkan hasil kluster
print(kmeans.labels_)
# Menambahkan kolom "kluster" dalam data frame ritel
retail["kluster"] = kmeans.labels_
retail.head()
# Out:
# [4 0 0 ... 3 0 0]
#    Unnamed: 0        player_name team_abbreviation  ...  ast_pct   season kluster
# 0           0      Dennis Rodman               CHI  ...    0.113  1996-97       4
# 1           1  Dwayne Schintzius               LAC  ...    0.048  1996-97       0
# 2           2       Earl Cureton               TOR  ...    0.148  1996-97       0
# 3           3        Ed O'Bannon               DAL  ...    0.077  1996-97       0
# 4           4        Ed Pinckney               MIA  ...    0.040  1996-97       0
#
# [5 rows x 19 columns]

# %%
output = plt.scatter(x_scaled[:,0], 
x_scaled[:,1], s = 100, c = retail.kluster, marker = "o", alpha = 1,)
centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c='red', s=200, alpha=1 , marker="s");
plt.title("Hasil Klustering K-Means")
plt.xlabel("Scaled reb")
plt.ylabel("Scaled ast")
plt.colorbar (output)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **Evaluasi Data**

# %%
import numpy as np 
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Aal1305/Tugas-Data-Saintis/main/all_seasons.csv'
df = pd.read_csv("https://raw.githubusercontent.com/Aal1305/Tugas-Data-Saintis/main/all_seasons.csv") 
df.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation  ...  ts_pct  ast_pct   season
# 0           0      Dennis Rodman               CHI  ...   0.479    0.113  1996-97
# 1           1  Dwayne Schintzius               LAC  ...   0.430    0.048  1996-97
# 2           2       Earl Cureton               TOR  ...   0.376    0.148  1996-97
# 3           3        Ed O'Bannon               DAL  ...   0.399    0.077  1996-97
# 4           4        Ed Pinckney               MIA  ...   0.611    0.040  1996-97
#
# [5 rows x 22 columns]

# %%
class HypothesisTest(object):
    
    def __init__(self, data):
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)
        
    def PValue(self, iters = 1000):
        self.test_stats = [self.TestStatistic(self.RunModel()) for _ in range(iters)]
        count = sum(1 for x in self.test_stats if x >= self.actual)
        return count / iters
    
    def TestStatistic(self, data):
        raise UnimplementedMethodException()
        
    def MakeModel(self):
        pass
    
    def RunModel(self):
        raise UnimplementedMethodException()

# %%
class CorrPermute(HypothesisTest):
    
    def TestStatistic(self, data):
        xs, ys = data
        test_stat = abs(correlation(xs, ys))
        return test_stat
    
    def RunModel(self):
        xs, ys = self.data
        xs = np.random.permutation(xs)
        return xs, ys
    
def correlation(x, y):
    std_x = np.std(x)
    std_y = np.std(y)
    if std_x and std_y > 0:
        return covariance(x, y) / std_x / std_y
    else:
        return 0
    
def de_mean(x):
    x_bar = np.mean(x)
    return [x_i - x_bar for x_i in x]

def covariance(x, y):
    n = len(x)
    return np.dot(de_mean(x), de_mean(y)) / (n - 1)

# %%
rs = df['reb']
ws = df['ast']

ct = CorrPermute((rs, ws))
pvalue = ct.PValue()

# %%
print('The P-Value is: ', pvalue)
# Out:
# The P-Value is:  0.0

# %% [markdown]
# **Memprediksi reb dan ast**

# %% [markdown]
# Penggunaan Linear least square :
#
# *    Linear least score digunakan untuk mengetahui korelasi dalam mengukur kekuatan dan tanda suatu hubungan antar variabel.
# *   Linear least square digunakan untuk meminimalkan MSE (mean squared error).

# %%
def LeastSquares(xs, ys):
    meanx, varx = np.mean(xs), np.var(xs)
    meany = np.mean(ys)
    
    slope = covariance(xs, ys) / varx
    inter = meany - slope * meanx
    
    return inter, slope

def FitLine(xs, inter, slope):
    fit_xs = np.sort(xs)
    fit_ys = inter + slope * fit_xs
    
    return fit_xs, fit_ys

# %%
inter, slope = LeastSquares(ws, rs)
fit_xs, fit_ys = FitLine(ws, inter, slope)

print('intercept is: {} and slope is: {}'.format(inter, slope))
# Out:
# intercept is: 2.996874012060526 and slope is: 0.3126137048101944

# %% [markdown]
# Pada linear least skor di atas, didapatkan hasil intersepnya adalah lebih dari 2,9 dan slope-nya adalah lebih dari 0,31

# %% [markdown]
# **Residual**

# %%
def Residuals(xs, ys, inter, slope):
    xs = np.asarray(xs)
    ys = np.asarray(ys)
    res = ys - (inter + slope * xs)
    return res

# %%
res = Residuals(ws, rs, inter, slope)

# %% [markdown]
# **Memprediksi reb dan ast:**

# %%
print('RMSE if we predict the reading scores using the writing scores: ', np.std(res))
print('RMSE if we predict the reading scores without using the writing scores: ', np.std(rs))
# Out:
# RMSE if we predict the reading scores using the writing scores:  2.431750117669083
# RMSE if we predict the reading scores without using the writing scores:  2.495281864315445

# %% [markdown]
# Dari data di atas, dapat diinterpretasikan sebagai berikut :
#
# *   Nilai RMSE (Root Mean Square Error) lebih dari 2.43 jika menggunakan reb untuk memprediksi nilai dari ast.
# *   Nilai RMSE (Root Mean Square Error) lebih dari 14 jika tidak menggunakan Iast untuk memprediksi nilai dari reb.
#
# > Sehingga dari RMSE di atas, dapat disimpulkan bahwa lebih baik menggunakan ast untuk memprediksi nilai dari reb.

# %% [markdown]
# **koefisien Desterminasi**

# %% [markdown]
# >Koefisien determinasi merupakan metric yang digunakan untuk mendeterminasikan seberapa baik model kita

# %%
r_squared = 1 - (np.var(res) / np.var(rs))

print('The Coefficient of Determination or r^2 is: ', r_squared)
# Out:
# The Coefficient of Determination or r^2 is:  0.05027324936544697

# %% [markdown]
# Dari data di atas, nilai dari R^2 lebih dari 0, sehingga garis yang dihasilkan cocok untuk data ini sehingga garis ini dapat digunakan untuk memprediksi reb.

# %% [markdown]
# **Visualisasi Plotting Garis/Line**

# %%
plt.figure(figsize = (15, 8))

plt.xlabel('reb')
plt.ylabel('ast')

plt.plot(fit_xs, fit_ys, color = 'black')
plt.scatter(ws, rs, color = 'red')

# %% [markdown]
# Gambar visualisasi di atas, menunjukkan bahwa garis yang dihasilkan cocok dengan diagram pada visualisasi data sebelumnya.
