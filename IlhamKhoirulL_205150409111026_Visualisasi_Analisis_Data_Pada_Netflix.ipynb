# %% [markdown]
# <a href="https://colab.research.google.com/github/nanangyudi/2020pds_d/blob/main/IlhamKhoirulL_205150409111026_Visualisasi_Analisis_Data_Pada_Netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deskripsi tujuan bisnis
#
# ---
# Dataset ini digunakan untuk mengetahui informasi data statistik pada Netflix

# %% [markdown]
# # Analisa pendekatan
#
# ---
#  Pada eksplorasi data ini, menggunakan pendekatan ilmu statistika yang dinamakan dengan Exploratory Data Analysis (EDA). EDA merupakan proses eksplorasi data yang bertujuan untuk memahami isi dan komponen penyusun data. Umumnya EDA dapat dilakukan dalam berbagai cara, yaitu :
#  1. Univariat Analysis — analisis deskriptif dengan satu variabel.
#  2. Bivariat Analysis — analisis relasi dengan dua variabel yang biasanya dengan target variabel.
#  3. Multivariat Analysis — analisis yang menggunakan lebih dari atau sama dengan tiga variabel.
#
# Namun, tidak ada metode atau urutan baku yang digunakan dalam melakukan EDA, yang perlu diperhatikan adalah semakin banyak informasi yang dikumpulkan dari data yang akan diolah, maka semakin baik pula pemahaman kita terhadap data tersebut. Proses memahami data tersebut dapat dilakukan atau dipermudah dengan cara menggunakan ilmu statistika. Karena dengan emnggunakan ilmu statistika kita mampu mempelajari bagaimana cara merencanakan, mengumpulkan, menganalisis, lalu menginterpretasikan, dan mempresentasikan data.

# %% [markdown]
# # Pengumpulan Data
#
# ---
# Dataset diambil dari website keggle.com
#
# link sumber dataset : https://www.kaggle.com/niharika41298/netflix-visualizations-recommendation-eda
#
# link csv dataset : https://raw.githubusercontent.com/ilhamkl/DataSains/main/netflix_titles.csv

# %% [markdown]
# ## **Persiapan Data Eksplorasi Data**

# %% [markdown]
# # Mengimpor Library
#
# ---
# Berikut ini adalah libary yang digunakan untuk mengeksplorasi data Netflix ini:
# 1. Pandas dan Numphy, digunakan untuk mempermudah dalam pemrosesan data numerik dan analisis data.
# 2. Matplotlib dan Seaborn, digunakan untuk menciptakan visualisasi data sehingga dapat mempermudah dalam memahami data.

# %% [markdown]
# **Mengimport Library**

# %%
#import library
import numpy as np # aljabar linear
import pandas as pd # untuk data prosesing
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Memuat file csv menggunakan url dari github.**

# %%
#load file csv
url='https://raw.githubusercontent.com/ilhamkl/DataSains/main/netflix_titles.csv'

# %% [markdown]
# **Menampilkan dataset dari file csv**

# %%
#memuat set data pada file csv
netflix_df=pd.read_csv(url)
netflix_df.head()
# Out:
#     show_id  ...                                        description
# 0  81145628  ...  Before planning an awesome wedding for his gra...
# 1  80117401  ...  Jandino Asporaat riffs on the challenges of ra...
# 2  70234439  ...  With the help of three human allies, the Autob...
# 3  80058654  ...  When a prison ship crash unleashes hundreds of...
# 4  80125979  ...  When nerdy high schooler Dani finally attracts...
#
# [5 rows x 12 columns]

# %%
netflix_df.tail()
# Out:
#        show_id  ...                                        description
# 6229  80000063  ...  This parody of first-person shooter games, mil...
# 6230  70286564  ...  Marc Maron stars as Marc Maron, who interviews...
# 6231  80116008  ...  Nursery rhymes and original music for children...
# 6232  70281022  ...  Set during the Russian Revolution, this comic ...
# 6233  70153404  ...  This hit sitcom follows the merry misadventure...
#
# [5 rows x 12 columns]

# %% [markdown]
# **Menampilkan dimensi pada dataset**

# %%
#melihat dimensi data
netflix_df.shape
# Out:
# (6234, 12)

# %% [markdown]
# **Menampilkan nama kolom yang ada pada dataset**

# %%
#melihat kolom
netflix_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# **Melihat data kosong pada kolom**
#
# ---
# Informasi yang didapatkan:
# 1. Jumlah Baris dan Kolom data
# 2. Nama variabel kolom
# 3. Tipe data tiap kolom
# 4. Memori yang dipakai
# 5. Jumlah Missing Value

# %%
#melihat nilai kosong
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %% [markdown]
# **Melihat jumlah data kosong pada kolom**

# %%
#missing value
netflix_df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# **Melihat jumlah data pada setiap kolom**

# %%
#jumlah keseluruhan dataset
netflix_df.count()
# Out:
# show_id         6234
# type            6234
# title           6234
# director        4265
# cast            5664
# country         5758
# date_added      6223
# release_year    6234
# rating          6224
# duration        6234
# listed_in       6234
# description     6234
# dtype: int64

# %% [markdown]
# **Mean** adalah jumlah dari seluruh data continous (numerical) dibagi dengan jumlah data yang ada. Mean adalah measure of central yang paling sering digunakan untuk data numerical

# %%
netflix_df.mean()
# Out:
# show_id         7.670368e+07
# release_year    2.013359e+03
# dtype: float64

# %% [markdown]
# **Median** adalah nilai tengah dari suatu data numerical yang diurutkan. jika jumlah data ganjil, maka nilai median tepat berada tengah dari data, sedangkan apabila genap maka nilai median berada diantara kedua nilai yang berada ditengah. Median lebih sering digunakan jika mean tidak mampu menjelaskan data kita dengan baik.

# %%
netflix_df.median()
# Out:
# show_id         80163367.0
# release_year        2016.0
# dtype: float64

# %% [markdown]
# **Melihat hubungan antar kolom**

# %%
sns.pairplot(netflix_df)

# %% [markdown]
# **Melihat Jumlah data dan visualisasi data antara Acara TV dan Film di Netflix**

# %%
netflix_shows=netflix_df[netflix_df['type']=='TV Show']

# %%
netflix_movies=netflix_df[netflix_df['type']=='Movie']

# %%
#analisis acara tv dan film pada netflix
sns.set(style="darkgrid")
ax = sns.countplot(x="type", data=netflix_df, palette="Set2")

# %% [markdown]
# **Visualisasi data jumlah intesitas update konten pada Netflix pertahun**

# %%
#perbaruan konten pada netflix
netflix_date = netflix_shows[['date_added']].dropna()
netflix_date['year'] = netflix_date['date_added'].apply(lambda x : x.split(', ')[-1])
netflix_date['month'] = netflix_date['date_added'].apply(lambda x : x.lstrip().split(' ')[0])

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'][::-1]
df = netflix_date.groupby('year')['month'].value_counts().unstack().fillna(0)[month_order].T
plt.figure(figsize=(10, 7), dpi=200)
plt.pcolor(df, cmap='afmhot_r', edgecolors='white', linewidths=2) # heatmap
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns, fontsize=7, fontfamily='serif')
plt.yticks(np.arange(0.5, len(df.index), 1), df.index, fontsize=7, fontfamily='serif')

plt.title('Update Konten Netflix Pertahun', fontsize=12, fontfamily='sans', fontweight='bold', position=(0.20, 1.0+0.02))
cbar = plt.colorbar()

cbar.ax.tick_params(labelsize=8) 
cbar.ax.minorticks_on()
plt.show()

# %% [markdown]
# **Visualisasi data, untuk mengetahui jumlah rating usia pada konten netflix**

# %%
#analisis rating usia
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(x="rating", data=netflix_movies, palette="Set2", order=netflix_movies['rating'].value_counts().index[0:15])

# %% [markdown]
# **Visualisasi peringkat 10 teratas negara pembuat film yang tayang di Netflix**

# %%
countries={}
netflix_movies['country']=netflix_movies['country'].fillna('Unknown')
cou=list(netflix_movies['country'])
for i in cou:
    #print(i)
    i=list(i.split(','))
    if len(i)==1:
        if i in list(countries.keys()):
            countries[i]+=1
        else:
            countries[i[0]]=1
    else:
        for j in i:
            if j in list(countries.keys()):
                countries[j]+=1
            else:
                countries[j]=1

# %%
countries_fin={}
for country,no in countries.items():
    country=country.replace(' ','')
    if country in list(countries_fin.keys()):
        countries_fin[country]+=no
    else:
        countries_fin[country]=no
        
countries_fin={k: v for k, v in sorted(countries_fin.items(), key=lambda item: item[1], reverse= True)}

# %%
#10 peringkat teratas negara pembuat film pada netflix
plt.figure(figsize=(8,8))
ax = sns.barplot(x=list(countries_fin.keys())[0:10],y=list(countries_fin.values())[0:10])
ax.set_xticklabels(list(countries_fin.keys())[0:10],rotation = 90)
# Out:
# [Text(0, 0, 'UnitedStates'),
#  Text(1, 0, 'France'),
#  Text(2, 0, 'UnitedKingdom'),
#  Text(3, 0, 'Canada'),
#  Text(4, 0, 'Germany'),
#  Text(5, 0, 'Belgium'),
#  Text(6, 0, 'China'),
#  Text(7, 0, 'Spain'),
#  Text(8, 0, 'India'),
#  Text(9, 0, 'Australia')]

# %% [markdown]
# **Visualisasi data untuk mengetahui jumlah serial terbanyak yang tayang di Netflix**

# %%
features=['title','duration']
durations= netflix_shows[features]

durations['no_of_seasons']=durations['duration'].str.replace(' Season','')

#durations['no_of_seasons']=durations['no_of_seasons'].astype(str).astype(int)
durations['no_of_seasons']=durations['no_of_seasons'].str.replace('s','')

# %%
durations['no_of_seasons']=durations['no_of_seasons'].astype(str).astype(int)

# %%
t=['title','no_of_seasons']
top=durations[t]

top=top.sort_values(by='no_of_seasons', ascending=False)


#acara tv yang memiliki jumlah musim terbanyak
top20=top[0:20]
top20.plot(kind='bar',x='title',y='no_of_seasons', color='red')
# Out:
# <AxesSubplot:xlabel='title'>

# %% [markdown]
# # **Evaluasi Model**
#
# ---
# - Kumpulan dataset ini terdiri dari acara TV dan film yang tersedia di Netflix hingga tahun 2019.
#
# - Bedasarkan eksplorasi yang telah dilakukan, menunjukkan bahwa jumlah acara TV lebih sedikit daripada jumlah film yang tayang di Netflix.
#
# - Setiap tahunnya mengalami peningkatan jumlah rilisan konten hingga tahun 2019. Pada tahun 2019 dan bulan Januari dan Desember merupakan ketika konten yang dirilis relatif lebih sedikit. Oleh karena itu, bulan-bulan tersebut mungkin merupakan pilihan yang bagus untuk para produser konten film/acara tv untuk menayang produk mereka karena konten yang dirilis tidak banyak pada bulan tersebut.
#
# - Jumlah rating usia terbesar yaitu pada rating 'TV-MA'. "TV-MA" adalah rating yang diberikan oleh TV Parental Guidelines untuk program televisi yang dirancang hanya untuk pemirsa dewasa. Jumlah rating usia Kedua terbesar adalah 'TV-14' yaitu untuk konten yang mungkin tidak pantas untuk anak-anak di bawah usia 14 tahun. Kemudian jumlah rating usia terbesar ketiga adalah rating 'R' yang sangat populer. Konten dengan rating R adalah film yang telah dinilai memiliki materi yang mungkin tidak sesuai untuk anak di bawah usia 17 tahun.
